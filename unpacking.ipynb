# %%
import matplotlib.pyplot as plt

# %%
data= [(1, 2, 3), (20, 30, 40)]
data
# Out:
# [(1, 2, 3), (20, 30, 40)]

# %%
data= [(1, 2, 3), (20, 30, 40)]
plt.scatter(data[0], data[1]);

# %%
data= [(1, 2, 3), (20, 30, 40)]
x = data[0]
y = data[1]
plt.scatter(x, y);

# %%
data= [(1, 2, 3), (20, 30, 40)]
x, y = data
plt.scatter(x, y);

# %%
data= [(1, 2, 3), (20, 30, 40)]
plt.scatter(*data);
