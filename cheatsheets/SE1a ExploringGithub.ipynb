# %% [markdown]
# # Intro to GitHub
# ## Browsing GitHub Repositories
#
# adfaf

# %% [markdown]
# ### Searching for Repositories

# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.random.randn(100000)
plt.hist(data, bins=50);

# %% [markdown]
# GitHub has some pretty good search functionality for the software it hosts!  You can search software by keywords, filter for specific programming languages, sort by popularity, and even look for specific lines of code!  Let's try it out. \
#
#
# Hello!

# %% [markdown]
# ![search](imgs/github_search.png)

# %% [markdown]
# #### Exercises
#
# For each of the search requests below (after the Q), find the repository and copy-paste the url after the **A:** line.  You can edit text by double-clicking on the box, or clicking once on the text box then pressing the Enter key on the keyboard.

# %% [markdown]
# **Q:** Get the URL for a Github repo that contains a Python library that helps with video editing
#
# **A:** https://github.com/nickdelgrosso/crab_pipeline

# %% [markdown]
# **Q:** Get the URL for a Github repo that contains Jupyter Notebooks that help teach how to learn Python for social science research.
#
# **A:** Hello!

# %% [markdown]
# **Q:** Which URL is the link to the "Awesome" list of python data science software?
#
# **A:**

# %% [markdown]
# ### Browsing Repositories
#
# A GitHub repository is essentially the same as a directory on your computer; it contains subdirectories and various files. In the case of code, usually these files are text files, but it can also contain images and various data files.
#
# Every repository has an organization or user name and a repository name.  For example, in the repo shown in the image below, you can see the following information and more:
#
#   - Organization: wind-python
#   - Repo Name: windpowerlib
#   - Number of Forks (how many times a copy was made by others): 71
#   - Number of Commits (how many times the project was updated): 1523
#
# ![repo](imgs/github_repo.png)
#
# Additionally, you can open folders and files by clicking on their names, or even search inside the repo (in the same search bar we used before).  Let's try it out, exploring a couple repos and get comfortable finding information in them.

# %% [markdown]
# #### Exercises

# %% [markdown]
# Answer the following questions about the following repo:  https://github.com/python/cpython

# %% [markdown]
# **Q:** What GitHub organization owns this repo?
#
# **A:**

# %% [markdown]
# **Q:** What is the name of this repo (often considered the project's name)?
#
# **A:**

# %% [markdown]
# **Q:** How many times have people cloned ("forked") their own copies of this source code on GitHub?
#
# **A:**

# %% [markdown]
# **Q:** How many contributors have added or edited code to this project on GitHub?
#
# **A:**

# %% [markdown]
# **Q**: How many different programming languages are used in this project?  Which languages make up the top 95% of the codebase?
#
# **A**:

# %% [markdown]
# Answer the following questions about the following repo:  https://github.com/pandas-dev/pandas

# %% [markdown]
# **Q:** What GitHub organization owns this repo?
#
# **A:**

# %% [markdown]
# **Q:** What is the name of this repo (often considered the project's name)?
#
# **A:**

# %% [markdown]
# **Q:** How many times have people cloned ("forked") their own copies of this source code on GitHub?
#
# **A:**

# %% [markdown]
# **Q:** How many contributors have added or edited code to this project on GitHub?
#
# **A:**

# %% [markdown]
# **Q**: How many different programming languages are used in this project?  Which languages make up the top 95% of the codebase?
#
# **A**:

# %% [markdown]
# ### Scanning the README
#
# Every software project should contain a text file called "README".  What should you do when you see this file?  Well, read it, of course!  To help encourage reading READMEs, GitHub automatically displays the contents of the README file when you access the repo: it's the text underneath the list of files, so be sure to scroll down to see the text.
#
# At the very least, a README should tell you:
#   1. Why the software project exists
#   2. Who it's made for
#   3. What the software does (hopefully with an example or two)
#   4. How to intall it on your computer
#   5. Where to find more-detailed documentation
#
#
# ![readme](imgs/github_readme.png)

# %% [markdown]
# #### Exercises
#
# Let's take a look at the following software's README: https://github.com/wind-python/windpowerlib, and copy-paste the relevant parts of the readme into the answer of each question.

# %% [markdown]
# **Q:** What does this software do?
#
# **A:** _________

# %% [markdown]
# **Q:** How do you install the software on your computer?
#
# **A:**

# %% [markdown]
# **Q:** What's an example of this software's functionality?
#
# **A:**

# %% [markdown]
# **Q:** Where can you find more-detailed documentation?
#
# **A:**

# %% [markdown]
# ### Browsing Files

# %% [markdown]
# Anything publicly available in GitHub is open source.  At the very least, this means we can read and learn from software's source code!  Let's take a look and see what we can find, as well as get more information about what kinds of permissions we have for using and modifying different software.
#
# ![files](imgs/github_file.png)

# %% [markdown]
# #### Exercises

# %% [markdown]
# **Ratcave**: Please answer the following questions about the repo at https://github.com/ratcave/ratcave

# %% [markdown]
# **Q:** There is a `utils` subfolder in one of the folders of this directory. What is it's web URL  (for example: https://github.com/nickdelgrosso/wordguess/tree/main/wordguess/data)?
#
# **A:**

# %% [markdown]
# **Q:** How many lines are in the `camera.py` file in the `ratcave` folder?
#
# **A:**

# %% [markdown]
# **Q:** Is this repo "open source"?  How can you tell?
#
# **A:**

# %% [markdown]
# **Q:** What license is this software offered under?  Is it offered free for companies to use commercially?  Is it allowed to be modified?
#
# **A:**

# %% [markdown]
# **Q:** What file contains the function called `calculate_normals`?  Find the function, then tell Github to select all the code in the function (click on the line number next to the function definition, then shift-click on the line number next to the last line in the function).  Copy the "perma-link" to those lines of code below.  (example for the `bind` method here: https://github.com/ratcave/ratcave/blob/master/ratcave/texture.py#L76-L83)
#
# **A:**

# %% [markdown]
# **Q:** find the `ProjectionBase` class and click the "Blame" button to view the last changes made to each line.  On what date was line 72 last edited?
#
# **A:**

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=3685da68-8645-45fd-87dd-4c628185bb7d' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
