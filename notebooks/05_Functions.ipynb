# %% [markdown]
# # Packaging Code into Functions
#
# ```python
# def my_function(x, y):   # Define a function name and its arguments x and y
#     z = x + y            # Make calculations in the function body
#     return z             # "Return" data out of the function.
# ```
# .

# %% [markdown]
# ### Functions without Arguments
#
# ```python
# def my_function():
#     return 'Hi!'
# ```
# .

# %% [markdown]
# **Exercises**: Write a function that doesn't raise an error in the assertion cells below it.

# %% [markdown]
# **get_gccta_sequence()**: Returns the sequence GCCTA

# %%
assert get_gccta_sequence() == 'GCCTA'   # Run this cell to check your function.  If no error is raised, it worked!
print('Passed!')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-8b133c4683c1> in <module>
# ----> 1 assert get_sequence() == 'GCCTA'   # Run this cell to check your function.  If no error is raised, it worked!
#       2 print('Passed!')
#
# NameError: name 'get_sequence' is not defined

# %% [markdown]
# **count_to_five()**: Return a list of values from 1 to 5

# %%
assert count_fo_five() == [1, 2, 3, 4, 5]
print('Passed!')

# %% [markdown]
# ### Functions with Arguments
#
# ```python
# def my_function(x, y):   # Define a function name and its arguments x and y
#     z = x + y            # Make calculations in the function body
#     return z             # "Return" data out of the function.
# ```
# .

# %% [markdown]
# **Exercises**

# %% [markdown]
# **format_seq()**

# %%
assert standardize_seq('gTgC') == 'GTGC'
assert standardize_seq('CCAaa') == 'CCAAA'
assert standardize_seq('aGaTt') == 'AGATT'
print('Passed!')

# %% [markdown]
# **get_first_codons()**

# %%
assert get_first_codons(['ATGCCA', 'AATTAGC']) == ['ATG', 'AAT']
assert get_first_codons(['GGAAGC', 'CCCAATA']) == ['GGA', 'CCC']
print('Passed!')

# %% [markdown]
# **is_positive()**

# %%
assert is_positive(32) == True
assert is_positive(-4) == False
assert is_positive(0) == False
print('Passed!')

# %% [markdown]
# **sum_each()**

# %%
assert sum_each([1, 2], [3, 4]) == [4, 6]
assert sum_each([-3, 5, 10], [10, 11, 12]) == [7, 16, 22]
print('Passed!')

# %% [markdown]
# **get_range()**

# %%
assert get_range(0, 5) == [0, 1, 2, 3, 4]
assert get_range(2, 4) == [2, 3]
print('Passed!')

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=e2b9254c-61b4-41cd-9cd0-b285172171b7' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
