# %%
x = [1, 2, 3]
type(x)

# %%
x = (1, 2, 3)
type(x)

# %%
import numpy as np

# %%
x = np.array([1, 2, 3])
type(x)

# %%
x = np.array((1, 2, 3))
type(x)

# %%
x = "Hello, world!"
type(x)

# %%
x = {1, 2, 2, 3, 3, 3}
len(x)

# %%
data = 42
Data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ae8505d45832> in <module>
#       1 data = 42
# ----> 2 Data
#
# NameError: name 'Data' is not defined

# %%
hello world!
# Out:
#   File "<ipython-input-8-f951b101989b>", line 1
#     hello world!
#               ^
# SyntaxError: invalid syntax

# %%
x = (1, 2, 3
# Out:
#   File "<ipython-input-7-6d2b32d05e00>", line 1
#     x = (1, 2, 3
#                 ^
# SyntaxError: unexpected EOF while parsing

# %%
import NumPy
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-9-b26bbea77e63> in <module>
# ----> 1 import NumPy
#
# ModuleNotFoundError: No module named 'NumPy'

# %%
x = 4
x ** 2
# Out:
# 16

# %%
# hello

# %%
max([4, 3, 2])
# Out:
# 4

# %%
min([max([2, 4, 1]), min([0, 5, 8])])
# Out:
# 0

# %%
len([min((1, 2)), max([3, 4, 5]), len([1, 1, 2, 4])])
# Out:
# 3

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=5f82c9ae-724d-4175-af3a-f3de86574cfe' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
