# %% [markdown]
# Okay, today I'm going to
#
# Great tutorial: https://matplotlib.org/stable/tutorials/introductory/pyplot.html

# %% [markdown]
# # Intro to Python Workshop
# ## Day 1

# %%
from IPython.display import HTML, display
display(HTML('''<table>
  <tr>
    <th>Time</th>
    <th>Topic</th>
  </tr>
  <tr>
    <td>9-30 - 10:45</td>
    <td>Getting Comfortable Interacting with Python in Notebooks</td>
  </tr>
  <tr>
    <td>10:45 - 12:30</td>
    <td>1D Sequences & Descriptive Statistics</td>
  </tr>
  <tr>
    <td><b>12:30 - 2:00</b></td>
    <td><b>Lunch Break</b></td>
  </tr>
  <tr>
    <td>2:00 - 3:30</td>
    <td>Indexing and Slicing Sequences</td>
  </tr>
  <tr>
    <td>3:30 - 5:30</td>
    <td>Intro to Plotting with Matplotlib</td>
  </tr>
</table>'''))
# Out:
# <table>
#   <tr>
#     <th>Time</th>
#     <th>Topic</th>
#   </tr>
#   <tr>
#     <td>9-30 - 10:45</td>
#     <td>Getting Comfortable Interacting with Python in Notebooks</td>
#   </tr>
#   <tr>
#     <td>10:45 - 12:30</td>
#     <td>1D Sequences & Descriptive Statistics</td>
#   </tr>
#   <tr>
#     <td><b>12:30 - 2:00</b></td>
#     <td><b>Lunch Break</b></td>
#   </tr>
#   <tr>
#     <td>2:00 - 3:30</td>
#     <td>Indexing and Slicing Sequences</td>
#   </tr>
#   <tr>
#     <td>3:30 - 5:30</td>
#     <td>Intro to Plotting with Matplotlib</td>
#   </tr>
# </table>

# %%
from IPython.display import YouTubeVideo
YouTubeVideo(id='UGj0bOYPdCw')

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=5f82c9ae-724d-4175-af3a-f3de86574cfe' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
