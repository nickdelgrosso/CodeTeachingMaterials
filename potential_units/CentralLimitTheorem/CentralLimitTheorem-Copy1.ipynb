# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Central Limit Theorem
#
# Demonstrate that the means of any distribution comes from a normal distribution

# %% [markdown]
# **Requirements**
#   1. Get Data from a non-normal distribution and show that it isn't normal
#     - Histogram of Data, show not normal

# %% [markdown]
#
#   2. Get data from that distribution many times
#     - Get NDays number of dataset

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.arange(12).reshape(3, 4)
np.median(x, axis=1, keepdims=True).flatten()
# Out:
# array([1.5, 5.5, 9.5])

# %%
x = np.random.random(size=(100, 100))
plt.imshow(x, cmap="hsv");
plt.colorbar();

# %%
x = np.arange(12).reshape(3, 4)
np.transpose(x)
x.transpose()
plt.imshow(x.T);

# %%
x[0,:]
x[:, [0, 2]]
# Out:
# array([[ 0,  2],
#        [ 4,  6],
#        [ 8, 10]])

# %%
x[:, ::2]
# Out:
# array([[ 0,  2],
#        [ 4,  6],
#        [ 8, 10]])

# %%
n_samples = 5000
n_days = 3000
data = np.random.exponential(1.5, size=(n_samples, n_days))
plt.hist(data[:, :3], bins=31);

# %% [markdown]
#   3. Show that the means of those many datas are normal
#     - Histogram of NDays data means, show normal

# %%
data_means = np.mean(data, axis=1)
plt.hist(data_means, bins=31);
