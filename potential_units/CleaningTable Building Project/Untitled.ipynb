# %%
import pandas as pd
from collections import defaultdict

# %% [markdown]
# # Table Data Conversion
# **Name**: Nicholas A. Del Grosso
#
# **Date**: Sept. 6, 2018
#
# **Description**: A demonstration of cleaning an ill-formed automatic table extraction from Tabula in Python using the Pandas package.
#
# The Tabula software is used for extracting tables from PDFs. It is free, and can be found at https://tabula.technology/
#
# Pandas is a Python library for working with tables.  This is similar to the 'dplyr' library in R.  A tutorial for using it can be found here:
#
#   - https://www.datacamp.com/community/tutorials/pandas-tutorial-dataframe-python
#
#   - http://pandas.pydata.org/pandas-docs/stable/

# %% [markdown]
# ## Load Data
#
# Let's see what this looks like straight out of Tabula...

# %%
filename = 'tabula-buildingreportjul2228201851157.csv'
df = pd.read_csv(filename, dtype=str, na_filter='')
df.head(30)
# Out:
#                                Folder Number Sub Type       Work Proposed  \
# 0                                 18 830938 000 00 NB
# 1                                 18 830939 000 00 NB
# 2                         Owner: Porte Industries Ltd
# 3                       Owner: Romana Investments Ltd
# 4                      Owner: West Coast Planners Ltd
# 5                                 18 830943 000 00 NB
# 6                   Owner: Kingvision Enterprises Ltd
# 7                                 18 831140 000 00 NB
# 8   Applicant: Coso Investments Corp. (Michael Coq...
# 9                            Owner: Margaret L Tecson
# 10
# 11                      18 831401 000 00 B7 Apartment  Special Inspection
# 12  Owner: Pinnacle Living (Capstan Village) Lands...
# 13                                   Apartment Total:
# 14                          17 790304 000 01 B7 Hotel            Revision
# 15                              Applicant: Mike Amiri
# 16                       Owner: Maple Hospitality Inc
# 17    Contractor: MYK Construction Ltd (604) 729-8520
# 18                          18 821040 000 00 B7 Hotel          Alteration
# 19  Applicant: Vancouver Airport Marriot (Amin Lalji)
# 20            Owner: Vancouver Airport Marriott Hotel
# 21                                       Hotel Total:
# 22                 18 831000 000 00 NB Illegal Suites
# 23                                    Owner: Jie Yuan
# 24                              Illegal Suites Total:
# 25                             Folder Number Sub Type       Work Proposed
# 26                         18 828981 000 00 B9 Market          Alteration
# 27                             Applicant: Doug Buffie
# 28        Owner: Richmond Centre (6060minoru Blvd)Ltd
# 29                      Owner: Ari Richmond North Ltd
#
#    Unnamed: 2  Status  Issue Date Unnamed: 5  Constr. Value  \
# 0              Issued     7/24/18
# 1              Issued     7/24/18
# 2
# 3
# 4
# 5              Issued     7/24/18
# 6
# 7               Final     7/25/18
# 8
# 9
# 10                                         4
# 11              Final     7/27/18
# 12
# 13                                         1
# 14             Issued     7/26/18
# 15
# 16
# 17
# 18             Issued     7/23/18
# 19
# 20
# 21                                         2
# 22              Final     7/25/18
# 23
# 24                                         1
# 25             Status  Issue Date             Constr. Value
# 26             Issued     7/27/18                    10,000
# 27
# 28
# 29
#
#                     Unnamed: 7                              Folder Name
# 0                            0                            12111 3rd Ave
# 1                            0                   12417 No 2 Rd Unit 230
# 2
# 3
# 4
# 5                            0             12111 Bridgeport Rd Unit 110
# 6
# 7                            0                          9597 Francis Rd
# 8
# 9
# 10                           0
# 11                           0                     8628 Hazelbridge Way
# 12
# 13                           0
# 14                           0  8811 Bridgeport Rd - Building Design Mo
# 15
# 16
# 17
# 18                           0     7571 Westminster Hwy - Occupant Load
# 19
# 20
# 21                           0
# 22                           0                             6780 No 5 Rd
# 23
# 24                           0
# 25                 Folder Name
# 26  6060 Minoru Blvd Unit 1828
# 27
# 28
# 29

# %% [markdown]
# ## Clean Out "Unnamed" Columns

# %% [markdown]
# Merge Unnamed columns with adjacent columns, remove rows that contain co.umn names

# %%
df['Work Proposed'] = df['Work Proposed'].str.cat(df['Unnamed: 2'], sep='')
df = df[df['Folder Number Sub Type'].str.contains('Total:|Folder Number') == False]
df = df[df['Folder Number Sub Type'].astype(bool)]
df['Address'] = df['Unnamed: 7'].transform(lambda ss: '' if len(ss.strip()) < 2 else ss).str.cat(df['Folder Name'])
df['Constr. Value'] = df['Unnamed: 5'].str.cat(df['Constr. Value'], sep='')
df = df.drop(labels=['Unnamed: 2', 'Unnamed: 7', 'Unnamed: 5', 'Folder Name'], axis=1)
df.head(20)
# Out:
#                                Folder Number Sub Type       Work Proposed  \
# 0                                 18 830938 000 00 NB
# 1                                 18 830939 000 00 NB
# 2                         Owner: Porte Industries Ltd
# 3                       Owner: Romana Investments Ltd
# 4                      Owner: West Coast Planners Ltd
# 5                                 18 830943 000 00 NB
# 6                   Owner: Kingvision Enterprises Ltd
# 7                                 18 831140 000 00 NB
# 8   Applicant: Coso Investments Corp. (Michael Coq...
# 9                            Owner: Margaret L Tecson
# 11                      18 831401 000 00 B7 Apartment  Special Inspection
# 12  Owner: Pinnacle Living (Capstan Village) Lands...
# 14                          17 790304 000 01 B7 Hotel            Revision
# 15                              Applicant: Mike Amiri
# 16                       Owner: Maple Hospitality Inc
# 17    Contractor: MYK Construction Ltd (604) 729-8520
# 18                          18 821040 000 00 B7 Hotel          Alteration
# 19  Applicant: Vancouver Airport Marriot (Amin Lalji)
# 20            Owner: Vancouver Airport Marriott Hotel
# 22                 18 831000 000 00 NB Illegal Suites
#
#     Status Issue Date Constr. Value                                  Address
# 0   Issued    7/24/18                                          12111 3rd Ave
# 1   Issued    7/24/18                                 12417 No 2 Rd Unit 230
# 2
# 3
# 4
# 5   Issued    7/24/18                           12111 Bridgeport Rd Unit 110
# 6
# 7    Final    7/25/18                                        9597 Francis Rd
# 8
# 9
# 11   Final    7/27/18                                   8628 Hazelbridge Way
# 12
# 14  Issued    7/26/18                8811 Bridgeport Rd - Building Design Mo
# 15
# 16
# 17
# 18  Issued    7/23/18                   7571 Westminster Hwy - Occupant Load
# 19
# 20
# 22   Final    7/25/18                                           6780 No 5 Rd

# %% [markdown]
# The Address and Constr. Value columns are still a bit confused, with Addresses in some Constr. Value rows.  This needs to be cleaned up.

# %%
missing_address = df['Address'].eq('') & (df['Constr. Value'].str.strip())
df.loc[missing_address, 'Address'] = df.loc[missing_address, 'Constr. Value']
df.loc[missing_address, 'Constr. Value'] = '' 
df.loc[df['Constr. Value'] == '0', 'Constr. Value'] = ''
df.head(20)
# Out:
#                                Folder Number Sub Type       Work Proposed  \
# 0                                 18 830938 000 00 NB
# 1                                 18 830939 000 00 NB
# 2                         Owner: Porte Industries Ltd
# 3                       Owner: Romana Investments Ltd
# 4                      Owner: West Coast Planners Ltd
# 5                                 18 830943 000 00 NB
# 6                   Owner: Kingvision Enterprises Ltd
# 7                                 18 831140 000 00 NB
# 8   Applicant: Coso Investments Corp. (Michael Coq...
# 9                            Owner: Margaret L Tecson
# 11                      18 831401 000 00 B7 Apartment  Special Inspection
# 12  Owner: Pinnacle Living (Capstan Village) Lands...
# 14                          17 790304 000 01 B7 Hotel            Revision
# 15                              Applicant: Mike Amiri
# 16                       Owner: Maple Hospitality Inc
# 17    Contractor: MYK Construction Ltd (604) 729-8520
# 18                          18 821040 000 00 B7 Hotel          Alteration
# 19  Applicant: Vancouver Airport Marriot (Amin Lalji)
# 20            Owner: Vancouver Airport Marriott Hotel
# 22                 18 831000 000 00 NB Illegal Suites
#
#     Status Issue Date Constr. Value                                  Address
# 0   Issued    7/24/18                                          12111 3rd Ave
# 1   Issued    7/24/18                                 12417 No 2 Rd Unit 230
# 2
# 3
# 4
# 5   Issued    7/24/18                           12111 Bridgeport Rd Unit 110
# 6
# 7    Final    7/25/18                                        9597 Francis Rd
# 8
# 9
# 11   Final    7/27/18                                   8628 Hazelbridge Way
# 12
# 14  Issued    7/26/18                8811 Bridgeport Rd - Building Design Mo
# 15
# 16
# 17
# 18  Issued    7/23/18                   7571 Westminster Hwy - Occupant Load
# 19
# 20
# 22   Final    7/25/18                                           6780 No 5 Rd

# %% [markdown]
# ## Extract Values from Non-Tabular Organization

# %% [markdown]
# The rows in "Folder Number Sub Type" contain more than one type of data.  Let's turn that column into multiple columns.

# %%
def extract_owners(nameseq):
    names = defaultdict(lambda: defaultdict(list))
    for name in nameseq:
        keyval = name.split(': ')
        if len(keyval) == 1:
            currname = keyval[0]
        else:
            key, val = keyval
            names[currname][key + 's'].append(val)
    return pd.DataFrame(names).T.fillna('').transform(lambda ll: ll.str.join(', '))

names = extract_owners(df['Folder Number Sub Type'].tolist())
df.set_index('Folder Number Sub Type', inplace=True)
# df.append(names)
df = pd.merge(names, df, left_index=True, right_index=True).reset_index()
df.head(20)
# Out:
#                                       index  \
# 0   16 734158 000 02 B7 One Family Dwelling
# 1   16 750521 000 00 B7 One Family Dwelling
# 2   16 752300 000 01 B7 One Family Dwelling
# 3                17 762301 000 01 B9 Retail
# 4             17 781953 000 01 BB Warehouse
# 5   17 783416 000 02 B7 Single Family/Suite
# 6                 17 790304 000 01 B7 Hotel
# 7   17 792047 000 00 B7 Single Family/Suite
# 8                18 802241 000 00 B8 Office
# 9   18 817691 000 00 B7 One Family Dwelling
# 10  18 819123 000 00 B7 One Family Dwelling
# 11                18 821040 000 00 B7 Hotel
# 12  18 822926 000 00 B7 One Family Dwelling
# 13           18 824460 000 00 B2 Restaurant
# 14  18 824672 000 00 B7 One Family Dwelling
# 15  18 824673 000 00 B7 One Family Dwelling
# 16           18 824847 000 00 B2 Restaurant
# 17  18 825263 000 00 B7 One Family Dwelling
# 18  18 826000 000 00 B7 One Family Dwelling
# 19           18 827634 000 00 B2 Restaurant
#
#                                  Applicants  \
# 0       Metro Van Con Ltd (Bhupinder Johal)
# 1     Penta Builders Group (Patrick Mullin)
# 2        Insite Architecture (Geoffrey Lee)
# 3                             Pattie Dehaan
# 4                               Steve Kalsi
# 5                              Yan Min Yang
# 6                                Mike Amiri
# 7                              Maryem Ahbib
# 8          Seng Tsoi Architects (Seng Tsoi)
# 9   Barstow Construction Ltd (Russ Barstow)
# 10                            Kai Ming Wang
# 11   Vancouver Airport Marriot (Amin Lalji)
# 12                           Michael Fernie
# 13                               Jeff Cheng
# 14                        Arun Jeyachandran
# 15
# 16                        Joyce Bao Xin Lin
# 17                          Sukhdev Dhingra
# 18                         Wayne De Angelis
# 19                               Sanny Chan
#
#                                           Contractors             Occupiers  \
# 0           Metro Van Construction Ltd (604) 825-4651
# 1             Penta Builders Group Inc (604) 244-9594
# 2
# 3                          Mavacon Inc (450) 902-1999
# 4   Frise Construction & Consulting Co Ltd (604) 7...
# 5                              Jun Ren (604) 721-7932
# 6                 MYK Construction Ltd (604) 729-8520
# 7       Professional Home Builders Ltd (604) 600-7270
# 8             Mansouri Enterprises Inc (604) 298-8388
# 9             Barstow Construction Ltd (778) 892-5462
# 10                   Dayu Holdings Ltd (778) 885-7733
# 11
# 12            GRN Pool & Landscape Ltd (604) 866-7062
# 13                                                     6 Pack Entertainment
# 14                     Karma Homes Ltd (604) 278-7400
# 15                     Karma Homes Ltd (604) 278-7400
# 16   Prosperous Square Development Ltd (778) 885-5186
# 17
# 18            Hi-Bond Construction Ltd (604) 473-7761
# 19       Final Choice Construction Inc (604) 324-1101
#
#                                                Owners  \
# 0   Lakhbir S Bath, Harpreet K Bath, Manjit K Bath...
# 1                                            Jin L Gu
# 2
# 3   Richmond Centre (6060minoru Blvd)Ltd, Ari Rich...
# 4                               Mason Investments Ltd
# 5                              Xuefang Su, Yan M Yang
# 6                               Maple Hospitality Inc
# 7                                      Jasjit S Uppal
# 8                                      0989705 Bc Ltd
# 9            Brandon M Crossley, Stephanie L Crossley
# 10                                         Kai M Wang
# 11                   Vancouver Airport Marriott Hotel
# 12                 Michael L Fernie, Carolyn J Fernie
# 13                              Sawarne Lumber Co Ltd
# 14          Arun M Jeyachandran, Sonia P Jeyachandran
# 15          Arun M Jeyachandran, Sonia P Jeyachandran
# 16                                          Mei R Wei
# 17  Danny K Dhingra, Sukhdev S Dhingra, Kanta K Dh...
# 18                                      Lawrence K Ho
# 19                         Fairchild Developments Ltd
#
#                  Work Proposed  Status Issue Date Constr. Value  \
# 0                     Revision  Issued    7/26/18
# 1                          New  Issued    7/23/18       435,305
# 2                     Revision  Issued    7/25/18
# 3                     Revision  Issued    7/25/18
# 4                     Revision  Issued    7/24/18
# 5                     Revision  Issued    7/26/18
# 6                     Revision  Issued    7/26/18
# 7                          New  Issued    7/23/18       444,441
# 8                          New  Issued    7/23/18     1,000,000
# 9                    NewIssued            7/24/18
# 10            AlterationIssued            7/23/18
# 11                  Alteration  Issued    7/23/18
# 12   Inground Swimming PIssued            7/25/18
# 13                  Alteration  Issued    7/27/18
# 14                   NewIssued            7/25/18
# 15  Garages and Carport Issued            7/25/18
# 16                  Alteration  Issued    7/24/18
# 17              AdditionIssued            7/24/18
# 18                  Alteration  Issued    7/26/18
# 19                  Alteration  Issued    7/25/18
#
#                                      Address
# 0        10191 Blundell Rd - Bldg Design Mod
# 1                           11740 Pintail Dr
# 2    10381 Hollywell Dr---Building Design Mo
# 3                06060 Minoru Blvd Unit 1758
# 4      13900 Bridgeport Rd---Bldg Design Mod
# 5   8271 Leslie Rd---Building Design Modific
# 6    8811 Bridgeport Rd - Building Design Mo
# 7                           10640 Gilmore Cr
# 8     7960 Alderbridge Way - Temporary Sales
# 9                412,21510871 Bonavista Gate
# 10                    10,0004251 Lancelot Dr
# 11      7571 Westminster Hwy - Occupant Load
# 12                    50,00012391 Phoenix Dr
# 13  013180 Mitchell Rd Unit 115---Occupant L
# 14                    248,1163031 Chatham St
# 15                     26,6803031 Chatham St
# 16            50,0008181 Cambie Rd Unit 2250
# 17                   67,93811891 Seabrook Cr
# 18                    4,00022460 Rathburn Dr
# 19     200,0004151 Hazelbridge Way Unit 1428

# %% [markdown]
# There is more data in the first column than I noticed--both an ID number and the type of dwelling are there.  These should also be in seperate columns.

# %%
def split_at_last_digit(ss):
    bb = list(map(str.isdigit, ss))
    try:
        idx = len(bb) - bb[::-1].index(True)
        return ss[:idx], ss[idx:]
    except ValueError:
        return '', ss

    
df = pd.DataFrame(df['index'].apply(split_at_last_digit).tolist(), columns=['ID', 'Building Type']).join(df)
df = df.drop(['index'], axis=1)
df.head(20)
# Out:
#                      ID         Building Type  \
# 0   16 734158 000 02 B7   One Family Dwelling
# 1   16 750521 000 00 B7   One Family Dwelling
# 2   16 752300 000 01 B7   One Family Dwelling
# 3   17 762301 000 01 B9                Retail
# 4      17 781953 000 01          BB Warehouse
# 5   17 783416 000 02 B7   Single Family/Suite
# 6   17 790304 000 01 B7                 Hotel
# 7   17 792047 000 00 B7   Single Family/Suite
# 8   18 802241 000 00 B8                Office
# 9   18 817691 000 00 B7   One Family Dwelling
# 10  18 819123 000 00 B7   One Family Dwelling
# 11  18 821040 000 00 B7                 Hotel
# 12  18 822926 000 00 B7   One Family Dwelling
# 13  18 824460 000 00 B2            Restaurant
# 14  18 824672 000 00 B7   One Family Dwelling
# 15  18 824673 000 00 B7   One Family Dwelling
# 16  18 824847 000 00 B2            Restaurant
# 17  18 825263 000 00 B7   One Family Dwelling
# 18  18 826000 000 00 B7   One Family Dwelling
# 19  18 827634 000 00 B2            Restaurant
#
#                                  Applicants  \
# 0       Metro Van Con Ltd (Bhupinder Johal)
# 1     Penta Builders Group (Patrick Mullin)
# 2        Insite Architecture (Geoffrey Lee)
# 3                             Pattie Dehaan
# 4                               Steve Kalsi
# 5                              Yan Min Yang
# 6                                Mike Amiri
# 7                              Maryem Ahbib
# 8          Seng Tsoi Architects (Seng Tsoi)
# 9   Barstow Construction Ltd (Russ Barstow)
# 10                            Kai Ming Wang
# 11   Vancouver Airport Marriot (Amin Lalji)
# 12                           Michael Fernie
# 13                               Jeff Cheng
# 14                        Arun Jeyachandran
# 15
# 16                        Joyce Bao Xin Lin
# 17                          Sukhdev Dhingra
# 18                         Wayne De Angelis
# 19                               Sanny Chan
#
#                                           Contractors             Occupiers  \
# 0           Metro Van Construction Ltd (604) 825-4651
# 1             Penta Builders Group Inc (604) 244-9594
# 2
# 3                          Mavacon Inc (450) 902-1999
# 4   Frise Construction & Consulting Co Ltd (604) 7...
# 5                              Jun Ren (604) 721-7932
# 6                 MYK Construction Ltd (604) 729-8520
# 7       Professional Home Builders Ltd (604) 600-7270
# 8             Mansouri Enterprises Inc (604) 298-8388
# 9             Barstow Construction Ltd (778) 892-5462
# 10                   Dayu Holdings Ltd (778) 885-7733
# 11
# 12            GRN Pool & Landscape Ltd (604) 866-7062
# 13                                                     6 Pack Entertainment
# 14                     Karma Homes Ltd (604) 278-7400
# 15                     Karma Homes Ltd (604) 278-7400
# 16   Prosperous Square Development Ltd (778) 885-5186
# 17
# 18            Hi-Bond Construction Ltd (604) 473-7761
# 19       Final Choice Construction Inc (604) 324-1101
#
#                                                Owners  \
# 0   Lakhbir S Bath, Harpreet K Bath, Manjit K Bath...
# 1                                            Jin L Gu
# 2
# 3   Richmond Centre (6060minoru Blvd)Ltd, Ari Rich...
# 4                               Mason Investments Ltd
# 5                              Xuefang Su, Yan M Yang
# 6                               Maple Hospitality Inc
# 7                                      Jasjit S Uppal
# 8                                      0989705 Bc Ltd
# 9            Brandon M Crossley, Stephanie L Crossley
# 10                                         Kai M Wang
# 11                   Vancouver Airport Marriott Hotel
# 12                 Michael L Fernie, Carolyn J Fernie
# 13                              Sawarne Lumber Co Ltd
# 14          Arun M Jeyachandran, Sonia P Jeyachandran
# 15          Arun M Jeyachandran, Sonia P Jeyachandran
# 16                                          Mei R Wei
# 17  Danny K Dhingra, Sukhdev S Dhingra, Kanta K Dh...
# 18                                      Lawrence K Ho
# 19                         Fairchild Developments Ltd
#
#                  Work Proposed  Status Issue Date Constr. Value  \
# 0                     Revision  Issued    7/26/18
# 1                          New  Issued    7/23/18       435,305
# 2                     Revision  Issued    7/25/18
# 3                     Revision  Issued    7/25/18
# 4                     Revision  Issued    7/24/18
# 5                     Revision  Issued    7/26/18
# 6                     Revision  Issued    7/26/18
# 7                          New  Issued    7/23/18       444,441
# 8                          New  Issued    7/23/18     1,000,000
# 9                    NewIssued            7/24/18
# 10            AlterationIssued            7/23/18
# 11                  Alteration  Issued    7/23/18
# 12   Inground Swimming PIssued            7/25/18
# 13                  Alteration  Issued    7/27/18
# 14                   NewIssued            7/25/18
# 15  Garages and Carport Issued            7/25/18
# 16                  Alteration  Issued    7/24/18
# 17              AdditionIssued            7/24/18
# 18                  Alteration  Issued    7/26/18
# 19                  Alteration  Issued    7/25/18
#
#                                      Address
# 0        10191 Blundell Rd - Bldg Design Mod
# 1                           11740 Pintail Dr
# 2    10381 Hollywell Dr---Building Design Mo
# 3                06060 Minoru Blvd Unit 1758
# 4      13900 Bridgeport Rd---Bldg Design Mod
# 5   8271 Leslie Rd---Building Design Modific
# 6    8811 Bridgeport Rd - Building Design Mo
# 7                           10640 Gilmore Cr
# 8     7960 Alderbridge Way - Temporary Sales
# 9                412,21510871 Bonavista Gate
# 10                    10,0004251 Lancelot Dr
# 11      7571 Westminster Hwy - Occupant Load
# 12                    50,00012391 Phoenix Dr
# 13  013180 Mitchell Rd Unit 115---Occupant L
# 14                    248,1163031 Chatham St
# 15                     26,6803031 Chatham St
# 16            50,0008181 Cambie Rd Unit 2250
# 17                   67,93811891 Seabrook Cr
# 18                    4,00022460 Rathburn Dr
# 19     200,0004151 Hazelbridge Way Unit 1428

# %% [markdown]
# ## Save Data to Excel

# %%
df.to_excel(filename.split('-')[1] + '.xlsx')
